# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
dt=pd.read_excel(r"C:\Users\91630\Dropbox\My PC (LAPTOP-VVGODUG5)\Downloads\lab2.xlsx", sheet_name="thyroid0387_UCI", na_values = "not available")
dt
# Out:
#      Record ID  age sex on thyroxine query on thyroxine  \
# 0    840801013   29   F            f                  f
# 1    840801014   29   F            f                  f
# 2    840801042   41   F            f                  f
# 3    840803046   36   F            f                  f
# 4    840803047   32   F            f                  f
# ..         ...  ...  ..          ...                ...
# 995  841031002   41   F            f                  f
# 996  841031010   41   F            f                  f
# 997  841031030   20   F            f                  f
# 998  841031031   20   F            f                  f
# 999  841031032   73   F            f                  f
#
#     on antithyroid medication sick pregnant thyroid surgery I131 treatment  \
# 0                           f    f        f               f              f
# 1                           f    f        f               f              f
# 2                           f    f        f               f              f
# 3                           f    f        f               f              f
# 4                           f    f        f               f              f
# ..                        ...  ...      ...             ...            ...
# 995                         f    f        f               f              f
# 996                         f    f        f               f              f
# 997                         f    f        t               f              f
# 998                         f    f        f               f              f
# 999                         f    f        f               f              f
#
#      ... TT4 measured  TT4 T4U measured   T4U FTI measured  FTI TBG measured  \
# 0    ...            f    ?            f     ?            f    ?            f
# 1    ...            t  128            f     ?            f    ?            f
# 2    ...            f    ?            f     ?            f    ?            t
# 3    ...            f    ?            f     ?            f    ?            t
# 4    ...            f    ?            f     ?            f    ?            t
# ..   ...          ...  ...          ...   ...          ...  ...          ...
# 995  ...            t  148            t  1.44            t  103            f
# 996  ...            t  9.7            t  1.46            t  6.6            f
# 997  ...            f    ?            f     ?            f    ?            t
# 998  ...            t  201            t  0.84            t  240            f
# 999  ...            t   85            t   0.9            t   94            f
#
#     TBG referral source     Condition
# 0     ?           other  NO CONDITION
# 1     ?           other  NO CONDITION
# 2    11           other  NO CONDITION
# 3    26           other  NO CONDITION
# 4    36           other             S
# ..   ..             ...           ...
# 995   ?            STMW  NO CONDITION
# 996   ?           other             F
# 997  30           other  NO CONDITION
# 998   ?             SVI            AK
# 999   ?             SVI  NO CONDITION
#
# [1000 rows x 31 columns]

# %%
dt.head()
# Out:
#    Record ID  age sex on thyroxine query on thyroxine  \
# 0  840801013   29   F            f                  f
# 1  840801014   29   F            f                  f
# 2  840801042   41   F            f                  f
# 3  840803046   36   F            f                  f
# 4  840803047   32   F            f                  f
#
#   on antithyroid medication sick pregnant thyroid surgery I131 treatment  ...  \
# 0                         f    f        f               f              f  ...
# 1                         f    f        f               f              f  ...
# 2                         f    f        f               f              f  ...
# 3                         f    f        f               f              f  ...
# 4                         f    f        f               f              f  ...
#
#   TT4 measured  TT4 T4U measured T4U FTI measured FTI TBG measured TBG  \
# 0            f    ?            f   ?            f   ?            f   ?
# 1            t  128            f   ?            f   ?            f   ?
# 2            f    ?            f   ?            f   ?            t  11
# 3            f    ?            f   ?            f   ?            t  26
# 4            f    ?            f   ?            f   ?            t  36
#
#   referral source     Condition
# 0           other  NO CONDITION
# 1           other  NO CONDITION
# 2           other  NO CONDITION
# 3           other  NO CONDITION
# 4           other             S
#
# [5 rows x 31 columns]

# %%
print((dt["TSH"].unique()))
print("--"*50)
print((dt["T3"].unique()))
# Out:
# [0.3 1.6 '?' 0.7 1.2 1.9 1 0.5 2.6 68 1.5 5.9 0.05 4 0.4 0.8 0.2 3
#  9.599999 140 0.6 1.7 2.5 6.8 2.1 1.1 9.799999 3.7 0.1 0.35 90 1.3 2.7 2.9
#  0.25 5.8 2 0.9 3.2 7.4 1.8 5 70 6.5 11.599999 4.2 88 2.2 53 16.5 8.4 4.1
#  3.3 80 176 30 11 6 71 9.099999 10.7 4.9 3.4 1.83 4.6 1.4 14 3.5 46 18 170
#  19.199999 7.5 145 7.9 19 48 25 7.3 6.7 153 35 3.8 2.3 9.2 12 5.5
#  15.299999 0.15 10.299999 430 213 37 216 26 4.3 2.4 47 8.2 14.4 17.4 100
#  13.2 41 3.1 22 45 4.5 24 65 4.4 56 11.4 5.2 5.6 8.299999 400 260 5.4 8
#  6.6 8.5 5.1 138 42 44 2.8 10 54 3.9 150]
# ----------------------------------------------------------------------------------------------------
# ['?' 1.9 2.6 1.8 1.7 2.3 2.4 2.9 2 2.1 1.6 0.1 1.4 1.2 1.5 1.3 2.5 2.7 2.2
#  2.8 3.2 0.4 0.8 1 1.1 3.7 4.4 3 3.1 3.6 7.6 0.9 4.2 0.5 0.6 0.3 0.7 3.8
#  0.2 4.1 6.6 4.7 8.599999 3.3 4.3 0.05 3.4]

# %%
print((dt["FTI"].unique()))
print("--"*50)
print((dt["TT4"].unique()))

print((dt["T4U"].unique()))
print("**"*50)
print((dt["FTI"].unique()))
print()
print((dt["TBG"].unique()))
# Out:
# ['?' 47 85 84 96 105 95 106 176 129 100 69 39 91 90 93 66 121 92 173 117
#  31 113 67 101 126 123 149 68 86 132 131 116 97 124 136 142 104 7.5 107 73
#  110 130 88 128 122 102 134 163 63 354 81 109 114 133 170 99 111 108 161
#  78 148 98 135 80 127 213 119 65 89 143 316 155 172 150 103 120 258 5 272
#  263 166 138 52 164 337 94 118 182 41 70 144 10 4 13 87 140 74 152 77 3 82
#  145 64 79 147 54 83 634 650 12 61 11 115 35 17 165 167 153 44 3.4 55 71
#  253 75 2.5 197 24 156 237 203 112 141 3.5 190 37 45 193 57 76 160 6 200
#  485 49 158 137 428 450 174 189 202 159 196 154 139 34 222 184 178 146 125
#  21 157 51 839 332 151 305 299 266 32 53 370 22 168 60 187 171 220 169 232
#  254 345 194 211 217 550 23 257 188 192 179 218 208 6.6 240]
# ----------------------------------------------------------------------------------------------------
# ['?' 128 116 76 83 133 105 122 48 90 79 104 88 107 126 113 150 93 157 80
#  91 47 39 71 111 86 136 163 118 82 33 134 60 102 97 115 132 114 94 145 106
#  87 120 121 152 98 109 139 131 112 64 7.5 68 99 92 95 100 184 81 308 57
#  170 130 51 144 73 63 78 129 85 125 196 153 96 127 108 250 141 110 101 210
#  140 74 188 3.9 117 84 138 119 27 89 236 32 55 72 44 158 69 9 6 15 149 13
#  61 182 4 178 135 70 151 56 59 213 77 222 195 14 12 40 67 16 167 148 147
#  123 50 65 66 7.6 4.1 49 75 202 3 169 200 24 242 162 103 143 186 124 58 35
#  180 359 43 225 137 166 302 62 206 52 155 142 261 176 22 260 159 54 287
#  230 36 172 296 21 154 183 198 174 208 245 217 11 207 42 228 46 201 212 23
#  333 38 168 41 175 146 211 181 156 9.7]
# ['?' 1.02 1.06 0.94 1.08 0.84 1.13 1.07 0.87 0.89 0.62 0.91 0.68 1 1.38
#  0.79 0.95 1.57 0.92 1.48 1.1 0.7 1.01 1.05 0.96 0.78 1.4 0.66 0.86 0.76
#  0.9 1.16 1.12 0.98 1.04 1.26 0.83 0.97 0.93 0.88 0.73 1.29 1.3 0.75 0.8
#  1.83 1.03 0.61 1.44 1.18 0.59 0.81 0.64 1.2 0.82 1.19 0.99 1.56 1.22 0.71
#  1.32 0.67 0.32 1.11 0.85 0.52 1.15 1.21 0.77 0.69 1.51 1.33 0.55 1.45
#  1.24 1.79 0.72 1.73 1.27 1.68 1.09 1.43 0.35 0.3 1.28 0.2 1.41 1.14 0.53
#  1.52 1.23 0.74 1.53 1.62 1.66 0.4 1.86 1.59 0.29 0.34 1.17 1.76 0.57 0.63
#  1.71 0.31 0.49 1.31 1.34 0.5 1.75 1.36 0.36 1.42 0.6 1.74 1.46]
# ****************************************************************************************************
# ['?' 47 85 84 96 105 95 106 176 129 100 69 39 91 90 93 66 121 92 173 117
#  31 113 67 101 126 123 149 68 86 132 131 116 97 124 136 142 104 7.5 107 73
#  110 130 88 128 122 102 134 163 63 354 81 109 114 133 170 99 111 108 161
#  78 148 98 135 80 127 213 119 65 89 143 316 155 172 150 103 120 258 5 272
#  263 166 138 52 164 337 94 118 182 41 70 144 10 4 13 87 140 74 152 77 3 82
#  145 64 79 147 54 83 634 650 12 61 11 115 35 17 165 167 153 44 3.4 55 71
#  253 75 2.5 197 24 156 237 203 112 141 3.5 190 37 45 193 57 76 160 6 200
#  485 49 158 137 428 450 174 189 202 159 196 154 139 34 222 184 178 146 125
#  21 157 51 839 332 151 305 299 266 32 53 370 22 168 60 187 171 220 169 232
#  254 345 194 211 217 550 23 257 188 192 179 218 208 6.6 240]
#
# ['?' 11 26 36 21 28 23 18 33 20 19 30 29 24 9.299999 25 53 27]

# %%
dt['TSH'] = dt['TSH'].replace('?', float('nan'))

print(dt['TSH'])
# Out:
# 0       0.3
# 1       1.6
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 995     0.1
# 996    53.0
# 997     NaN
# 998     0.1
# 999     3.3
# Name: TSH, Length: 1000, dtype: float64

# %%
col_mean = dt['TSH'].mean()
col_mean
# Out:
# 6.5596384079096035

# %%
dt["TSH"].fillna(col_mean, inplace=True)

# %%
dt['TSH'] = dt['TSH'].replace('?', float('nan'))
print(dt['TSH'].isnull())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: TSH, Length: 1000, dtype: bool

# %%
dt['T3'] = dt['T3'].replace('?', float('nan'))
print(dt["T3"])

col_mean = dt['T3'].mean()
print(col_mean)

dt['T3'].fillna(col_mean, inplace=True)

dt['T3'] = dt['T3'].replace('?', float('nan'))
# Out:
# 0      NaN
# 1      1.9
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 995    2.1
# 996    0.4
# 997    NaN
# 998    0.8
# 999    1.2
# Name: T3, Length: 1000, dtype: float64
# 1.8222431065162907

# %%
dt['FTI'] = dt['FTI'].replace('?', float('nan'))
print(dt["FTI"])

col_mean = dt['FTI'].mean()
print(col_mean)

dt['FTI'].fillna(col_mean, inplace=True)

dt['FTI'] = dt['FTI'].replace('?', float('nan'))
# Out:
# 0      114.600887
# 1      114.600887
# 2      114.600887
# 3      114.600887
# 4      114.600887
#           ...
# 995    103.000000
# 996      6.600000
# 997    114.600887
# 998    240.000000
# 999     94.000000
# Name: FTI, Length: 1000, dtype: float64
# 114.60088691796008

# %%
dt['TT4'] = dt['TT4'].replace('?', float('nan'))
print(dt["TT4"])

col_mean = dt['TT4'].mean()
print(col_mean)

dt['TT4'].fillna(col_mean, inplace=True)

dt['TT4'] = dt['TT4'].replace('?', float('nan'))
# Out:
# 0        NaN
# 1      128.0
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 995    148.0
# 996      9.7
# 997      NaN
# 998    201.0
# 999     85.0
# Name: TT4, Length: 1000, dtype: float64
# 106.44770833333334

# %%
dt['T4U'] = dt['T4U'].replace('?', float('nan'))
print(dt["TT4"])

col_mean =dt['T4U'].mean()
print(col_mean)

dt['T4U'].fillna(col_mean, inplace=True)

dt['T4U'] = dt['T4U'].replace('?', float('nan'))
# Out:
# 0      106.447708
# 1      128.000000
# 2      106.447708
# 3      106.447708
# 4      106.447708
#           ...
# 995    148.000000
# 996      9.700000
# 997    106.447708
# 998    201.000000
# 999     85.000000
# Name: TT4, Length: 1000, dtype: float64
# 0.972039911308204

# %%
dt['TT4']
# Out:
# 0      106.447708
# 1      128.000000
# 2      106.447708
# 3      106.447708
# 4      106.447708
#           ...
# 995    148.000000
# 996      9.700000
# 997    106.447708
# 998    201.000000
# 999     85.000000
# Name: TT4, Length: 1000, dtype: float64

# %%
dt['FTI'] = dt['FTI'].replace('?', float('nan'))
print(dt["FTI"])

col_mean = dt['FTI'].mean()
print(col_mean)

dt['FTI'].fillna(col_mean, inplace=True)

dt['FTI'] = dt['FTI'].replace('?', float('nan'))
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#        ...
# 995    103.0
# 996      6.6
# 997      NaN
# 998    240.0
# 999     94.0
# Name: FTI, Length: 1000, dtype: float64
# 114.60088691796008

# %%
dt['TBG'] = dt['TBG'].replace('?', float('nan'))
print(dt["TBG"])

col_mean = dt['TBG'].mean()
print(col_mean)

dt['TBG'].fillna(col_mean, inplace=True)

dt['TBG'] = dt['TBG'].replace('?', float('nan'))
# Out:
# 0       NaN
# 1       NaN
# 2      11.0
# 3      26.0
# 4      36.0
#        ...
# 995     NaN
# 996     NaN
# 997    30.0
# 998     NaN
# 999     NaN
# Name: TBG, Length: 1000, dtype: float64
# 26.23055552777778

# %%
dt.to_excel('updated_dataset.xlsx', index=False)

# %%
d1 = pd.read_excel("updated_dataset.xlsx")
d1
# Out:
#      Record ID  age sex on thyroxine query on thyroxine  \
# 0    840801013   29   F            f                  f
# 1    840801014   29   F            f                  f
# 2    840801042   41   F            f                  f
# 3    840803046   36   F            f                  f
# 4    840803047   32   F            f                  f
# ..         ...  ...  ..          ...                ...
# 995  841031002   41   F            f                  f
# 996  841031010   41   F            f                  f
# 997  841031030   20   F            f                  f
# 998  841031031   20   F            f                  f
# 999  841031032   73   F            f                  f
#
#     on antithyroid medication sick pregnant thyroid surgery I131 treatment  \
# 0                           f    f        f               f              f
# 1                           f    f        f               f              f
# 2                           f    f        f               f              f
# 3                           f    f        f               f              f
# 4                           f    f        f               f              f
# ..                        ...  ...      ...             ...            ...
# 995                         f    f        f               f              f
# 996                         f    f        f               f              f
# 997                         f    f        t               f              f
# 998                         f    f        f               f              f
# 999                         f    f        f               f              f
#
#      ... TT4 measured         TT4 T4U measured      T4U FTI measured  \
# 0    ...            f  106.447708            f  0.97204            f
# 1    ...            t  128.000000            f  0.97204            f
# 2    ...            f  106.447708            f  0.97204            f
# 3    ...            f  106.447708            f  0.97204            f
# 4    ...            f  106.447708            f  0.97204            f
# ..   ...          ...         ...          ...      ...          ...
# 995  ...            t  148.000000            t  1.44000            t
# 996  ...            t    9.700000            t  1.46000            t
# 997  ...            f  106.447708            f  0.97204            f
# 998  ...            t  201.000000            t  0.84000            t
# 999  ...            t   85.000000            t  0.90000            t
#
#             FTI TBG measured        TBG  referral source     Condition
# 0    114.600887            f  26.230556            other  NO CONDITION
# 1    114.600887            f  26.230556            other  NO CONDITION
# 2    114.600887            t  11.000000            other  NO CONDITION
# 3    114.600887            t  26.000000            other  NO CONDITION
# 4    114.600887            t  36.000000            other             S
# ..          ...          ...        ...              ...           ...
# 995  103.000000            f  26.230556             STMW  NO CONDITION
# 996    6.600000            f  26.230556            other             F
# 997  114.600887            t  30.000000            other  NO CONDITION
# 998  240.000000            f  26.230556              SVI            AK
# 999   94.000000            f  26.230556              SVI  NO CONDITION
#
# [1000 rows x 31 columns]

# %%
d1 = d1.replace('?', np.nan)


columns_that_are_in_question_mark = d1.columns[d1.isna().any()].tolist()

print("Columns containing '?' (NaN) values:")
print(columns_that_are_in_question_mark)
# Out:
# Columns containing '?' (NaN) values:
# ['sex']

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record ID                  1000 non-null   int64
#  1   age                        1000 non-null   int64
#  2   sex                        976 non-null    object
#  3   on thyroxine               1000 non-null   object
#  4   query on thyroxine         1000 non-null   object
#  5   on antithyroid medication  1000 non-null   object
#  6   sick                       1000 non-null   object
#  7   pregnant                   1000 non-null   object
#  8   thyroid surgery            1000 non-null   object
#  9   I131 treatment             1000 non-null   object
#  10  query hypothyroid          1000 non-null   object
#  11  query hyperthyroid         1000 non-null   object
#  12  lithium                    1000 non-null   object
#  13  goitre                     1000 non-null   object
#  14  tumor                      1000 non-null   object
#  15  hypopituitary              1000 non-null   object
#  16  psych                      1000 non-null   object
#  17  TSH measured               1000 non-null   object
#  18  TSH                        1000 non-null   float64
#  19  T3 measured                1000 non-null   object
#  20  T3                         1000 non-null   float64
#  21  TT4 measured               1000 non-null   object
#  22  TT4                        1000 non-null   float64
#  23  T4U measured               1000 non-null   object
#  24  T4U                        1000 non-null   float64
#  25  FTI measured               1000 non-null   object
#  26  FTI                        1000 non-null   float64
#  27  TBG measured               1000 non-null   object
#  28  TBG                        1000 non-null   float64
#  29  referral source            1000 non-null   object
#  30  Condition                  1000 non-null   object
# dtypes: float64(6), int64(2), object(23)
# memory usage: 242.3+ KB

# %%
selected_columns = ['age','TSH','T3','TT4','T4U','FTI','TBG']

d1[selected_columns].boxplot()


plt.title("Box Plots for Selected Columns")
plt.ylabel("Values")

# Show the plot
plt.show()

# %%
selected_columns = ['age','TSH','T3','TT4','T4U','FTI','TBG']  # Add all columns you want to transform

# Apply a logarithmic transformation (base 10) to all selected columns
for column in selected_columns:
    d1[column] = np.log10(d1[column])

# %%
selected_columns = ['age','TSH','T3','TT4','T4U','FTI','TBG']

# Create box plots for the selected columns
d1[selected_columns].boxplot()

# Customize the plot (optional)
plt.title("Box Plots for Selected Columns")
plt.ylabel("Values")

# Show the plot
plt.show()

# %%
mode_gender = d1['sex'].mode()[0]
d1['sex'].fillna(mode_gender, inplace=True)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record ID                  1000 non-null   int64
#  1   age                        1000 non-null   float64
#  2   sex                        1000 non-null   object
#  3   on thyroxine               1000 non-null   object
#  4   query on thyroxine         1000 non-null   object
#  5   on antithyroid medication  1000 non-null   object
#  6   sick                       1000 non-null   object
#  7   pregnant                   1000 non-null   object
#  8   thyroid surgery            1000 non-null   object
#  9   I131 treatment             1000 non-null   object
#  10  query hypothyroid          1000 non-null   object
#  11  query hyperthyroid         1000 non-null   object
#  12  lithium                    1000 non-null   object
#  13  goitre                     1000 non-null   object
#  14  tumor                      1000 non-null   object
#  15  hypopituitary              1000 non-null   object
#  16  psych                      1000 non-null   object
#  17  TSH measured               1000 non-null   object
#  18  TSH                        1000 non-null   float64
#  19  T3 measured                1000 non-null   object
#  20  T3                         1000 non-null   float64
#  21  TT4 measured               1000 non-null   object
#  22  TT4                        1000 non-null   float64
#  23  T4U measured               1000 non-null   object
#  24  T4U                        1000 non-null   float64
#  25  FTI measured               1000 non-null   object
#  26  FTI                        1000 non-null   float64
#  27  TBG measured               1000 non-null   object
#  28  TBG                        1000 non-null   float64
#  29  referral source            1000 non-null   object
#  30  Condition                  1000 non-null   object
# dtypes: float64(7), int64(1), object(23)
# memory usage: 242.3+ KB

# %%
numerical_columns = ['TSH','T3','TT4','T4U','FTI','TBG']  
for column in numerical_columns:
    d1[column] = (d1[column] - d1[column].min()) / (d1[column].max() - d1[column].min())

# %%
import pandas as pd
import numpy as np

# Assuming you have a DataFrame named 'df' with multiple numerical columns
# Example DataFrame:
# df = pd.DataFrame({'Age': [25, 30, 35, 40, 45, 50],
#                    'TSH': [2.5, 3.2, 1.8, 8.5, 2.0, 2.1],
#                    'T3': [2.0, 2.5, 2.3, 2.8, 2.2, 2.1],
#                    'TT4': [100, 120, 90, 200, 105, 110],
#                    'T4U': [0.95, 0.92, 0.96, 0.88, 0.94, 0.93],
#                    'FTI': [105, 130, 95, 230, 110, 118],
#                    'TBG': [15, 18, 12, 35, 16, 17]})

# Define a threshold for the Z-score (e.g., 2.5 or 3 for extreme outliers)
z_score_threshold = 2.5

# Create a new DataFrame to store the cleaned data
d1_cleaned = d1.copy()

# Iterate through selected numerical columns and remove outliers
for column in ['age', 'TSH', 'T3', 'TT4', 'T4U', 'FTI', 'TBG']:
    # Calculate the Z-score for the current column
    z_scores = np.abs((d1_cleaned[column] - d1_cleaned[column].mean()) / d1_cleaned[column].std())

    # Identify and remove rows with outliers based on the Z-score
    outlier_rows = z_scores > z_score_threshold
    d1_cleaned = d1_cleaned[~outlier_rows]

# Now, 'df_cleaned' contains your data with outliers removed from all selected columns

# %%
selected_columns = ['age','TSH','T3','TT4','T4U','FTI','TBG']

# Create box plots for the selected columns
d1_cleaned[selected_columns].boxplot()

# Customize the plot (optional)
plt.title("Box Plots for Selected Columns")
plt.ylabel("Values")

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np

# Assuming you have a DataFrame named 'df' with multiple numerical columns
# Example DataFrame:
# df = pd.DataFrame({'Age': [25, 30, 35, 40, 45, 50],
#                    'TSH': [2.5, 3.2, 1.8, 8.5, 2.0, 2.1],
#                    'T3': [2.0, 2.5, 2.3, 2.8, 2.2, 2.1],
#                    'TT4': [100, 120, 90, 200, 105, 110],
#                    'T4U': [0.95, 0.92, 0.96, 0.88, 0.94, 0.93],
#                    'FTI': [105, 130, 95, 230, 110, 118],
#                    'TBG': [15, 18, 12, 35, 16, 17]})

# Define a threshold for the Z-score (e.g., 2.5 or 3 for extreme outliers)
z_score_threshold = 1.5

# Create a new DataFrame to store the cleaned data
d1_cleaned2 = d1_cleaned.copy()

# Iterate through selected numerical columns and remove outliers
for column in ['age', 'TSH', 'T3', 'TT4', 'T4U', 'FTI', 'TBG']:
    # Calculate the Z-score for the current column
    z_scores = np.abs((d1_cleaned2[column] - d1_cleaned2[column].mean()) / d1_cleaned2[column].std())

    # Identify and remove rows with outliers based on the Z-score
    outlier_rows = z_scores > z_score_threshold
    d1_cleaned2 = d1_cleaned2[~outlier_rows]

# Now, 'df_cleaned' contains your data with outliers removed from all selected columns

# %%
selected_columns = ['age','TSH','T3','TT4','T4U','FTI','TBG']

# Create box plots for the selected columns
d1_cleaned2[selected_columns].boxplot()

# Customize the plot (optional)
plt.title("Box Plots for Selected Columns")
plt.ylabel("Values")

# Show the plot
plt.show()

# %%
d1.to_excel('no-outliers_normalized_nonullvalues.xlsx', index=False)

# %%
d1 = d1_cleaned2.copy()

# %%
columns_to_keep = ['TSH', 'T3', 'TT4', 'T4U', 'FTI', 'TBG']

# Use the DataFrame.drop method to remove unwanted columns
dt = dt[columns_to_keep]

# %%
min_max_scaler = lambda x: (x - x.min()) / (x.max() - x.min())
dt_normalized = dt.copy()
d1_normalized[d1_normalized.columns] = dt_normalized[dt_normalized.columns].apply(min_max_scaler)

# A4: Similarity Measures - Jaccard Coefficient and Simple Matching Coefficient
# Assuming you want to calculate these measures for the first two rows of the DataFrame

# Select the first two rows (or any rows you want to compare)
row1 = dt_normalized.iloc[0, :]
row2 = dt_normalized.iloc[1, :]

# Jaccard Coefficient
jaccard_coefficient = np.sum(np.minimum(row1, row2)) / np.sum(np.maximum(row1, row2))

# Simple Matching Coefficient
smc = np.sum(np.equal(row1, row2)) / len(row1)

print("Jaccard Coefficient:", jaccard_coefficient)
print("Simple Matching Coefficient:", smc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 min_max_scaler = lambda x: (x - x.min()) / (x.max() - x.min())
#       2 dt_normalized = dt.copy()
# ----> 3 d1_normalized[d1_normalized.columns] = dt_normalized[dt_normalized.columns].apply(min_max_scaler)
#       5 # A4: Similarity Measures - Jaccard Coefficient and Simple Matching Coefficient
#       6 # Assuming you want to calculate these measures for the first two rows of the DataFrame
#       7
#       8 # Select the first two rows (or any rows you want to compare)
#       9 row1 = dt_normalized.iloc[0, :]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[63], line 1, in <lambda>(x)
# ----> 1 min_max_scaler = lambda x: (x - x.min()) / (x.max() - x.min())
#       2 dt_normalized = dt.copy()
#       3 d1_normalized[d1_normalized.columns] = dt_normalized[dt_normalized.columns].apply(min_max_scaler)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11965, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11945 @doc(
#   11946     _num_doc,
#   11947     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11963     **kwargs,
#   11964 ):
# > 11965     return NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11365, in NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11357 def min(
#   11358     self,
#   11359     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11363     **kwargs,
#   11364 ):
# > 11365     return self._stat_function(
#   11366         "min",
#   11367         nanops.nanmin,
#   11368         axis,
#   11369         skipna,
#   11370         level,
#   11371         numeric_only,
#   11372         **kwargs,
#   11373     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1051, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1049         result = np.nan
#    1050 else:
# -> 1051     result = getattr(values, meth)(axis)
#    1053 result = _maybe_null_out(result, axis, mask, values.shape)
#    1054 return result
#
# File ~\anaconda3\Lib\site-packages\numpy\core\_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '<=' not supported between instances of 'float' and 'str'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import combinations



# Select the first 20 observation vectors
first_20 = dt.iloc[:20, :]

# A6: Calculate JC, SMC, and COS between pairs of vectors and create a heatmap
pairwise_jc = []
pairwise_smc = []
pairwise_cosine = []

for pair in combinations(first_20.index, 2):
    vector1 = first_20.loc[pair[0], :]
    vector2 = first_20.loc[pair[1], :]

    # Jaccard Coefficient
    intersection = sum((vector1 == 1) & (vector2 == 1))
    union = sum((vector1 == 1) | (vector2 == 1))

    # Avoid division by zero
    if union == 0:
        jc = 0.0
    else:
        jc = intersection / union

    pairwise_jc.append(jc)

    # Simple Matching Coefficient
    smc = sum(vector1 == vector2) / len(vector1)
    pairwise_smc.append(smc)

    # Cosine Similarity
    cosine_sim = 1 - cosine(vector1, vector2)
    pairwise_cosine.append(cosine_sim)

# Create a DataFrame for the pairwise similarity measures
pairwise_similarity_df = pd.DataFrame({
    'JC': pairwise_jc,
    'SMC': pairwise_smc,
    'COS': pairwise_cosine
})

# Create a heatmap plot
plt.figure(figsize=(10, 8))
sns.heatmap(pairwise_similarity_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Pairwise Similarity Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 9
#       4 from itertools import combinations
#       8 # Select the first 20 observation vectors
# ----> 9 first_20 = df.iloc[:20, :]
#      11 # A6: Calculate JC, SMC, and COS between pairs of vectors and create a heatmap
#      12 pairwise_jc = []
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import jaccard_score
from sklearn.metrics.pairwise import cosine_similarity

data = pd.read_excel(r"C:\Users\91630\Dropbox\My PC (LAPTOP-VVGODUG5)\Downloads\lab2.xlsx", sheet_name="thyroid0387_UCI", na_values = "not available")
vectors = data.iloc[:20, 1:-1] 
def jaccard_coefficient(vector1, vector2):
    intersection = np.logical_and(vector1, vector2)
    union = np.logical_or(vector1, vector2)
    return np.sum(intersection) / np.sum(union)
jc_matrix = np.zeros((20, 20))
smc_matrix = np.zeros((20, 20))
cosine_matrix = np.zeros((20, 20))
for i in range(20):
    for j in range(20):
        vector1 = vectors.iloc[i].astype(bool)
        vector2 = vectors.iloc[j].astype(bool)
        jc_matrix[i, j] = jaccard_coefficient(vector1, vector2)
        smc_matrix[i, j] = jaccard_score(vector1, vector2, average='binary')
        cosine_matrix[i, j] = cosine_similarity([vector1], [vector2])[0, 0]
plt.figure(figsize=(10, 8))
sns.heatmap(jc_matrix, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=False, yticklabels=False)
plt.title("Jaccard Coefficient Heatmap")
plt.show()
plt.figure(figsize=(10, 8))
sns.heatmap(smc_matrix, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=False, yticklabels=False)
plt.title("Simple Matching Coefficient Heatmap")
plt.show()
plt.figure(figsize=(10, 8))
sns.heatmap(cosine_matrix, annot=True, fmt=".2f", cmap="YlGnBu", xticklabels=False, yticklabels=False)
plt.title("Cosine Similarity Heatmap")
plt.show()
